# %%
import pandas
data = pandas.read_csv("volcanos.txt")
lat = list(data["LAT"])
lon = list(data["LON"])
for lt, ln in zip(lat, lon):
    print(lt, "and", ln)
# Out:
# 48.7767982 and -121.810997
# 48.1118011 and -121.1110001
# 46.8698006 and -121.7509995
# 46.1997986 and -122.1809998
# 46.20579910000001 and -121.4909973
# 45.8797989 and -122.0810013
# 45.929798100000006 and -121.8209991
# 45.3737984 and -121.6910019
# 44.691799200000005 and -121.8010025
# 44.4197998 and -121.7710037
# 44.3797989 and -121.9309998
# 44.331798600000006 and -121.8310013
# 44.2848015 and -121.8410034
# 44.1697998 and -121.7710037
# 44.099800099999996 and -121.7710037
# 43.978801700000005 and -121.6809998
# 43.7218018 and -121.2210007
# 43.569801299999995 and -121.8209991
# 43.5119019 and -120.8610001
# 43.240798999999996 and -122.10099790000001
# 43.471900899999994 and -120.7509995
# 43.3609009 and -120.6610031
# 42.9299011 and -122.1210022
# 44.4299011 and -110.6709976
# 43.0998993 and -118.7509995
# 43.1498985 and -117.4710007
# 42.9999008 and -117.8010025
# 43.419899 and -113.5009995
# 43.4999008 and -112.45099640000001
# 43.1799011 and -114.35099790000001
# ...
